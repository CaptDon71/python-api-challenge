# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 584

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"


    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Make the API request
        response = requests.get(city_url)
        city_weather = response.json()
        city_weather
        # Parse the JSON and retrieve data
        if response.status_code == 200:
            # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
            city_lat = city_weather['coord']['lat']
            city_lng = city_weather['coord']['lon']
            city_max_temp = city_weather['main']['temp_max']
            city_humidity = city_weather['main']['humidity']
            city_clouds = city_weather['clouds']['all']
            city_wind = city_weather['wind']['speed']
            city_country = city_weather['sys']['country']
            city_date = city_weather['dt']

            # Append the city information into city_data list
            city_data.append({
                "City": city,
                "Lat": city_lat,
                "Lng": city_lng,
                "Max Temp": city_max_temp,
                "Humidity": city_humidity,
                "Cloudiness": city_clouds,
                "Wind Speed": city_wind,
                "Country": city_country,
                "Date": city_date
            })

        else:
            print(f"City not found. Skipping {city_url}...")

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"Error occurred for city {city}: {e}")
        pass

    # Pause to avoid hitting API rate limits (1 second pause)
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | oyama
# Processing Record 2 of Set 1 | adamstown
# Processing Record 3 of Set 1 | kudahuvadhoo
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | rundu
# Processing Record 6 of Set 1 | edinburgh of the seven seas
# Processing Record 7 of Set 1 | hawaiian paradise park
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | saipan
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | mgandu
# Processing Record 13 of Set 1 | suoyarvi
# Processing Record 14 of Set 1 | stanley
# Processing Record 15 of Set 1 | aykhal
# Processing Record 16 of Set 1 | ancud
# Processing Record 17 of Set 1 | port mathurin
# Processing Record 18 of Set 1 | tobelo
# Processing Record 19 of Set 1 | chemolgan
# Processing Record 20 of Set 1 | blackmans bay
# Processing Record 21 of Set 1 | marion
# Processing Record 22 of Set 1 | college
# Processing Record 23 of Set 1 | acarau
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | kayangel
# Processing Record 27 of Set 1 | khanty-mansiysk
# Processing Record 28 of Set 1 | enewetak
# Processing Record 29 of Set 1 | kupang
# Processing Record 30 of Set 1 | olonkinbyen
# Processing Record 31 of Set 1 | quesada
# Processing Record 32 of Set 1 | cannonvale
# Processing Record 33 of Set 1 | cerritos
# Processing Record 34 of Set 1 | kovur
# Processing Record 35 of Set 1 | acapulco de juarez
# Processing Record 36 of Set 1 | iquique
# Processing Record 37 of Set 1 | verkhnevilyuysk
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | tazovsky
# Processing Record 40 of Set 1 | bayanhongor
# Processing Record 41 of Set 1 | margaret river
# Processing Record 42 of Set 1 | papatowai
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | viedma
# Processing Record 45 of Set 1 | waitangi
# Processing Record 46 of Set 1 | badger
# Processing Record 47 of Set 1 | dire
# Processing Record 48 of Set 1 | whitehorse
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | ribeira grande
# Processing Record 0 of Set 2 | homer
# Processing Record 1 of Set 2 | tocoa
# Processing Record 2 of Set 2 | grytviken
# Processing Record 3 of Set 2 | amga
# Processing Record 4 of Set 2 | kijang
# Processing Record 5 of Set 2 | kourou
# Processing Record 6 of Set 2 | wailua homesteads
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | san-pedro
# Processing Record 9 of Set 2 | chinoz
# Processing Record 10 of Set 2 | fale old settlement
# Processing Record 11 of Set 2 | changde
# Processing Record 12 of Set 2 | keflavik
# Processing Record 13 of Set 2 | muisne
# Processing Record 14 of Set 2 | rongelap
# Processing Record 15 of Set 2 | crane
# Processing Record 16 of Set 2 | west island
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | kingscliff
# Processing Record 19 of Set 2 | hamilton
# Processing Record 20 of Set 2 | cabo san lucas
# Processing Record 21 of Set 2 | nouadhibou
# Processing Record 22 of Set 2 | aldinga beach
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | olavarria
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | vallegrande
# Processing Record 27 of Set 2 | invercargill
# Processing Record 28 of Set 2 | bilara
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | vizinga
# Processing Record 26 of Set 4 | hadibu
# Processing Record 27 of Set 4 | palmer
# Processing Record 28 of Set 4 | san antonio de pale
# Processing Record 29 of Set 4 | weno
# Processing Record 30 of Set 4 | kill devil hills
# Processing Record 31 of Set 4 | anadyr
# Processing Record 32 of Set 4 | st. john's
# Processing Record 33 of Set 4 | lorengau
# Processing Record 34 of Set 4 | blagoveshchensk
# Processing Record 35 of Set 4 | mukalla
# Processing Record 36 of Set 4 | ta`u
# Processing Record 37 of Set 4 | usogorsk
# Processing Record 38 of Set 4 | ringkobing
# Processing Record 39 of Set 4 | goundam
# Processing Record 40 of Set 4 | cubuk
# Processing Record 41 of Set 4 | mutuali
# Processing Record 42 of Set 4 | hinatuan
# Processing Record 43 of Set 4 | elur
# Processing Record 44 of Set 4 | cockburn town
# Processing Record 45 of Set 4 | khandyga
# Processing Record 46 of Set 4 | udachny
# Processing Record 47 of Set 4 | colonia
# Processing Record 48 of Set 4 | akureyri
# Processing Record 49 of Set 4 | le port
# Processing Record 0 of Set 5 | port elizabeth
# Processing Record 1 of Set 5 | bemidji
# Processing Record 2 of Set 5 | port macquarie
# Processing Record 3 of Set 5 | kaa-khem
# Processing Record 4 of Set 5 | touros
# Processing Record 5 of Set 5 | toliara
# Processing Record 6 of Set 5 | tual
# Processing Record 7 of Set 5 | stawell
# Processing Record 8 of Set 5 | ahmadpur
# Processing Record 9 of Set 5 | santa rosa del sur
# Processing Record 10 of Set 5 | haiku-pauwela
# Processing Record 11 of Set 5 | la ronge
# Processing Record 12 of Set 5 | ifakara
# Processing Record 13 of Set 5 | plastun
# Processing Record 14 of Set 5 | queenstown
# Processing Record 15 of Set 5 | timimoun
# Processing Record 16 of Set 5 | san blas
# Processing Record 17 of Set 5 | baeza
# Processing Record 18 of Set 5 | grivenskaya
# Processing Record 19 of Set 5 | sarmiento
# Processing Record 20 of Set 5 | guerrero negro
# Processing Record 21 of Set 5 | taishan
# Processing Record 22 of Set 5 | suez
# Processing Record 23 of Set 5 | leh
# Processing Record 24 of Set 5 | praia da vitoria
# Processing Record 25 of Set 5 | klyuchi
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | mount isa
# Processing Record 28 of Set 5 | pauini
# Processing Record 29 of Set 5 | katsuura
# Processing Record 30 of Set 5 | hami
# Processing Record 31 of Set 5 | flying fish cove
# Processing Record 32 of Set 5 | lazaro cardenas
# Processing Record 33 of Set 5 | lerwick
# Processing Record 34 of Set 5 | bubaque
# Processing Record 35 of Set 5 | ezhva
# Processing Record 36 of Set 5 | groitzsch
# Processing Record 37 of Set 5 | inari
# Processing Record 38 of Set 5 | tadine
# Processing Record 39 of Set 5 | witu
# Processing Record 40 of Set 5 | longyearbyen
# Processing Record 41 of Set 5 | puyo
# Processing Record 42 of Set 5 | mana
# Processing Record 43 of Set 5 | kapuskasing
# Processing Record 44 of Set 5 | saudarkrokur
# Processing Record 45 of Set 5 | nizhniy kuranakh
# Processing Record 46 of Set 5 | harper
# Processing Record 47 of Set 5 | stephenville
# Processing Record 48 of Set 5 | at taj
# Processing Record 49 of Set 5 | anna regina
# Processing Record 0 of Set 6 | tsiombe
# Processing Record 1 of Set 6 | yelizovo
# Processing Record 2 of Set 6 | shanhecun
# Processing Record 3 of Set 6 | banyo
# Processing Record 4 of Set 6 | mwanza
# Processing Record 5 of Set 6 | wynyard
# Processing Record 6 of Set 6 | kenai
# Processing Record 7 of Set 6 | sesimbra
# Processing Record 8 of Set 6 | benghazi
# Processing Record 9 of Set 6 | port saint john's
# Processing Record 10 of Set 6 | prince albert
# Processing Record 11 of Set 6 | constantia
# Processing Record 12 of Set 6 | namibe
# Processing Record 13 of Set 6 | bor
# Processing Record 14 of Set 6 | ahau
# City not found. Skipping http://api.openweathermap.org/data/2.5/weather?q=ahau&appid=32e625436aae742f14f597fabf50d561&units=metric...
# Processing Record 15 of Set 6 | qamdo
# Processing Record 16 of Set 6 | usinsk
# Processing Record 17 of Set 6 | utrik
# Processing Record 18 of Set 6 | biloela
# Processing Record 19 of Set 6 | kiunga
# Processing Record 20 of Set 6 | abadan
# Processing Record 21 of Set 6 | jamestown
# Processing Record 22 of Set 6 | roma
# Processing Record 23 of Set 6 | lebu
# Processing Record 24 of Set 6 | muli
# Processing Record 25 of Set 6 | bikenibeu village
# Processing Record 26 of Set 6 | mumbwa
# Processing Record 27 of Set 6 | caraballeda
# Processing Record 28 of Set 6 | morehead city
# Processing Record 29 of Set 6 | mahanoro
# Processing Record 30 of Set 6 | barstow
# Processing Record 31 of Set 6 | aasiaat
# Processing Record 32 of Set 6 | kumbo
# Processing Record 33 of Set 6 | tanrake village
# City not found. Skipping http://api.openweathermap.org/data/2.5/weather?q=tanrake village&appid=32e625436aae742f14f597fabf50d561&units=metric...
# Processing Record 34 of Set 6 | island harbour
# Processing Record 35 of Set 6 | patterson
# Processing Record 36 of Set 6 | kulia village
# City not found. Skipping http://api.openweathermap.org/data/2.5/weather?q=kulia village&appid=32e625436aae742f14f597fabf50d561&units=metric...
# Processing Record 37 of Set 6 | port douglas
# Processing Record 38 of Set 6 | tranovaho
# City not found. Skipping http://api.openweathermap.org/data/2.5/weather?q=tranovaho&appid=32e625436aae742f14f597fabf50d561&units=metric...
# Processing Record 39 of Set 6 | qa'en
# Processing Record 40 of Set 6 | hayma'
# City not found. Skipping http://api.openweathermap.org/data/2.5/weather?q=hayma'&appid=32e625436aae742f14f597fabf50d561&units=metric...
# Processing Record 41 of Set 6 | gadzhiyevo
# Processing Record 42 of Set 6 | antofagasta
# Processing Record 43 of Set 6 | taco pozo
# Processing Record 44 of Set 6 | palencia
# Processing Record 45 of Set 6 | praya
# Processing Record 46 of Set 6 | sandakan
# Processing Record 47 of Set 6 | mariental
# Processing Record 48 of Set 6 | port hedland
# Processing Record 49 of Set 6 | tovarkovskiy
# Processing Record 0 of Set 7 | valreas
# Processing Record 1 of Set 7 | reggane
# Processing Record 2 of Set 7 | gilgit
# Processing Record 3 of Set 7 | margate
# Processing Record 4 of Set 7 | trappenkamp
# Processing Record 5 of Set 7 | kayyerkan
# Processing Record 6 of Set 7 | bethanie
# Processing Record 7 of Set 7 | sesheke
# Processing Record 8 of Set 7 | al lagowa
# Processing Record 9 of Set 7 | talcahuano
# Processing Record 10 of Set 7 | la mira
# Processing Record 11 of Set 7 | pontiac
# Processing Record 12 of Set 7 | kathmandu
# Processing Record 13 of Set 7 | moundou
# Processing Record 14 of Set 7 | cargados carajos
# City not found. Skipping http://api.openweathermap.org/data/2.5/weather?q=cargados carajos&appid=32e625436aae742f14f597fabf50d561&units=metric...
# Processing Record 15 of Set 7 | ciudad lazaro cardenas
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | bahia honda
# Processing Record 18 of Set 7 | woodland park
# Processing Record 19 of Set 7 | mili
# Processing Record 20 of Set 7 | minas de marcona
# Processing Record 21 of Set 7 | prineville
# Processing Record 22 of Set 7 | okhotsk
# Processing Record 23 of Set 7 | kapa'a
# Processing Record 24 of Set 7 | edirne
# Processing Record 25 of Set 7 | la'ie
# Processing Record 26 of Set 7 | crucecita
# Processing Record 27 of Set 7 | yemetsk
# Processing Record 28 of Set 7 | el jadid
# Processing Record 29 of Set 7 | tangalle
# Processing Record 30 of Set 7 | lluta
# Processing Record 31 of Set 7 | cabedelo
# Processing Record 32 of Set 7 | port lincoln
# Processing Record 33 of Set 7 | revda
# Processing Record 34 of Set 7 | neftekumsk
# Processing Record 35 of Set 7 | rey bouba
# Processing Record 36 of Set 7 | taoudenni
# Processing Record 37 of Set 7 | kismayo
# Processing Record 38 of Set 7 | champerico
# Processing Record 39 of Set 7 | hammerfest
# Processing Record 40 of Set 7 | luderitz
# Processing Record 41 of Set 7 
# Processing Record 21 of Set 9 | alofi
# Processing Record 22 of Set 9 | kasempa
# Processing Record 23 of Set 9 | langsa
# Processing Record 24 of Set 9 | santiago papasquiaro
# Processing Record 25 of Set 9 | pandan
# Processing Record 26 of Set 9 | santa ana
# Processing Record 27 of Set 9 | birao
# Processing Record 28 of Set 9 | tionk essil
# Processing Record 29 of Set 9 | saint-francois
# Processing Record 30 of Set 9 | terrace
# Processing Record 31 of Set 9 | semnan
# Processing Record 32 of Set 9 | catriel
# Processing Record 33 of Set 9 | sierra grande
# Processing Record 34 of Set 9 | umm kaddadah
# Processing Record 35 of Set 9 | plouzane
# Processing Record 36 of Set 9 | zhanaozen
# Processing Record 37 of Set 9 | ivdel'
# Processing Record 38 of Set 9 | mandera
# Processing Record 39 of Set 9 | ilhabela
# Processing Record 40 of Set 9 | yantarnyy
# Processing Record 41 of Set 9 | nailong
# Processing Record 42 of Set 9 | brookings
# Processing Record 43 of Set 9 | kamina
# Processing Record 44 of Set 9 | amantea
# Processing Record 45 of Set 9 | mata-utu
# Processing Record 46 of Set 9 | tanjung selor
# Processing Record 47 of Set 9 | lae
# Processing Record 48 of Set 9 | enid
# Processing Record 49 of Set 9 | taitung city
# Processing Record 0 of Set 10 | son la
# Processing Record 1 of Set 10 | puerto baquerizo moreno
# Processing Record 2 of Set 10 | perros-guirec
# Processing Record 3 of Set 10 | volya
# Processing Record 4 of Set 10 | peniche
# Processing Record 5 of Set 10 | nadym
# Processing Record 6 of Set 10 | booue
# Processing Record 7 of Set 10 | vorkuta
# Processing Record 8 of Set 10 | montmagny
# Processing Record 9 of Set 10 | westport
# Processing Record 10 of Set 10 | sur
# Processing Record 11 of Set 10 | severnoye
# Processing Record 12 of Set 10 | agat village
# Processing Record 13 of Set 10 | caleta de carquin
# Processing Record 14 of Set 10 | sao miguel do araguaia
# Processing Record 15 of Set 10 | guatire
# Processing Record 16 of Set 10 | sao paulo do potengi
# Processing Record 17 of Set 10 | carutapera
# Processing Record 18 of Set 10 | general mosconi
# Processing Record 19 of Set 10 | gornopravdinsk
# Processing Record 20 of Set 10 | puerto armuelles
# Processing Record 21 of Set 10 | dhidhdhoo
# Processing Record 22 of Set 10 | la junta
# Processing Record 23 of Set 10 | puerto aysen
# Processing Record 24 of Set 10 | khadyzhensk
# Processing Record 25 of Set 10 | karwar
# Processing Record 26 of Set 10 | nemuro
# Processing Record 27 of Set 10 | balikpapan
# Processing Record 28 of Set 10 | nar'yan-mar
# Processing Record 29 of Set 10 | brejo da madre de deus
# Processing Record 30 of Set 10 | cankaya
# Processing Record 31 of Set 10 | dakhla
# Processing Record 32 of Set 10 | muroto-misakicho
# Processing Record 33 of Set 10 | jianshui
# Processing Record 34 of Set 10 | ponta delgada
# Processing Record 35 of Set 10 | papao
# Processing Record 36 of Set 10 | ometepec
# Processing Record 37 of Set 10 | nishinoomote
# Processing Record 38 of Set 10 | bodaybo
# Processing Record 39 of Set 10 | pisco
# Processing Record 40 of Set 10 | dunedin
# Processing Record 41 of Set 10 | sao jose da coroa grande
# Processing Record 42 of Set 10 | gokceada
# Processing Record 43 of Set 10 | nagqu
# Processing Record 44 of Set 10 | kyshtovka
# Processing Record 45 of Set 10 | rodez
# Processing Record 46 of Set 10 | kamaishi
# Processing Record 47 of Set 10 | sitka
# Processing Record 48 of Set 10 | pizarro
# Processing Record 49 of Set 10 | tromso
# Processing Record 0 of Set 11 | arona
# Processing Record 1 of Set 11 | bernalillo
# Processing Record 2 of Set 11 | sechenovo
# Processing Record 3 of Set 11 | dixon
# Processing Record 4 of Set 11 | endasak
# Processing Record 5 of Set 11 | jacmel
# Processing Record 6 of Set 11 | santana
# Processing Record 7 of Set 11 | angaur state
# Processing Record 8 of Set 11 | makhambet
# Processing Record 9 of Set 11 | conceicao da barra
# Processing Record 10 of Set 11 | mwinilunga
# Processing Record 11 of Set 11 | lycksele
# Processing Record 12 of Set 11 | namsos
# Processing Record 13 of Set 11 | rosetta
# Processing Record 14 of Set 11 | porto sant'elpidio
# Processing Record 15 of Set 11 | tobi village
# City not found. Skipping http://api.openweathermap.org/data/2.5/weather?q=tobi village&appid=32e625436aae742f14f597fabf50d561&units=metric...
# Processing Record 16 of Set 11 | atasu
# Processing Record 17 of Set 11 | el bauga
# Processing Record 18 of Set 11 | yorkton
# Processing Record 19 of Set 11 | mawu
# Processing Record 20 of Set 11 | constitucion
# Processing Record 21 of Set 11 | port-gentil
# Processing Record 22 of Set 11 | atafu village
# Processing Record 23 of Set 11 | arawa
# Processing Record 24 of Set 11 | kokopo
# Processing Record 25 of Set 11 | srinivaspur
# Processing Record 26 of Set 11 | vingt cinq
# City not found. Skipping http://api.openweathermap.org/data/2.5/weather?q=vingt cinq&appid=32e625436aae742f14f597fabf50d561&units=metric...
# Processing Record 27 of Set 11 | sinabang
# Processing Record 28 of Set 11 | shuangjiang
# Processing Record 29 of Set 11 | nhamunda
# Processing Record 30 of Set 11 | grand falls-windsor
# Processing Record 31 of Set 11 | onega
# Processing Record 32 of Set 11 | gao
# Processing Record 33 of Set 11 | zeya
# Processing Record 34 of Set 11 | labasa
# Processing Record 35 of Set 11 | faya-largeau
# Processing Record 36 of Set 11 | north battleford
# Processing Record 37 of Set 11 | swift current
# Processing Record 38 of Set 11 | shalqar
# Processing Record 39 of Set 11 | polyarnyy
# Processing Record 40 of Set 11 | tchintabaraden
# Processing Record 41 of Set 11 | posto da mata
# Processing Record 42 of Set 11 | bridgewater
# Processing Record 43 of Set 11 | caleta olivia
# Processing Record 44 of Set 11 | sabang
# Processing Record 45 of Set 11 | sarpang
# Processing Record 46 of Set 11 | pirallahi
# Processing Record 47 of Set 11 | khorixas
# Processing Record 48 of Set 11 | qui nhon
# Processing Record 49 of Set 11 | verkhneural'sk
# Processing Record 0 of Set 12 | yuzhno-kurilsk
# Processing Record 1 of Set 12 | tame
# Processing Record 2 of Set 12 | eureka
# Processing Record 3 of Set 12 | naze
# Processing Record 4 of Set 12 | oranjemund
# Processing Record 5 of Set 12 | san luis de la loma
# Processing Record 6 of Set 12 | sinop
# Processing Record 7 of Set 12 | rudnichnyy
# Processing Record 8 of Set 12 | hasaki
# Processing Record 9 of Set 12 | gatesville
# Processing Record 10 of Set 12 | tucurui
# Processing Record 11 of Set 12 | afaahiti
# Processing Record 12 of Set 12 | heiligenhafen
# Processing Record 13 of Set 12 | el granada
# Processing Record 14 of Set 12 | el salto
# Processing Record 15 of Set 12 | charlestown
# Processing Record 16 of Set 12 | nova vicosa
# Processing Record 17 of Set 12 | nuuk
# Processing Record 18 of Set 12 | banda aceh
# Processing Record 19 of Set 12 | happy valley-goose bay
# Processing Record 20 of Set 12 | wolmaransstad
# Processing Record 21 of Set 12 | kununurra
# Processing Record 22 of Set 12 | borogontsy
# Processing Record 23 of Set 12 | chemin grenier
# Processing Record 24 of Set 12 | kerikeri
# Processing Record 25 of Set 12 | nevada
# Processing Record 26 of Set 12 | la grande
# Processing Record 27 of Set 12 | runing
# Processing Record 28 of Set 12 | letlhakeng
# Processing Record 29 of Set 12 | porto velho
# Processing Record 30 of Set 12 | launceston
# Processing Record 31 of Set 12 | totness
# Processing Record 32 of Set 12 | chosica
# Processing Record 33 of Set 12 | sambava
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         oyama  36.3000  139.8000     19.12        70          83
# 1     adamstown -25.0660 -130.1015     19.63        83          99
# 2  kudahuvadhoo   2.6708   72.8944     28.63        78          93
# 3     hithadhoo  -0.6000   73.0833     28.49        73         100
# 4         rundu -17.9333   19.7667     32.35        19          83
#
#    Wind Speed Country        Date
# 0        3.65      JP  1727107541
# 1        5.50      PN  1727107460
# 2        5.52      MV  1727107543
# 3        4.24      MV  1727107544
# 4        2.53      NA  1727107546

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               oyama  36.3000  139.8000     19.12        70          83
# 1           adamstown -25.0660 -130.1015     19.63        83          99
# 2        kudahuvadhoo   2.6708   72.8944     28.63        78          93
# 3           hithadhoo  -0.6000   73.0833     28.49        73         100
# 4               rundu -17.9333   19.7667     32.35        19          83
#
#          Wind Speed Country        Date
# City_ID
# 0              3.65      JP  1727107541
# 1              5.50      PN  1727107460
# 2              5.52      MV  1727107543
# 3              4.24      MV  1727107544
# 4              2.53     NaN  1727107546

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolor='black', marker='o')

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Temperature (2024-09-23)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolor='black', marker='o')

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Humidity (2024-09-23)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolor='black', marker='o')

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Cloudiness (2024-09-23)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolor='black', marker='o')

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Wind Speed (2024-09-23)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x, y, ann_x, ann_y, x_label='X-axis', y_label='Y-axis', title='Linear Regression Plot'):
    # Perform linear regression using arguments 
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    print(f'The r^2-value is: {r_value**2}')
    # Calculate predicted y values
    y_pred = slope * np.array(x) + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create the scatter plot
    plt.scatter(x, y, color='blue', edgecolor='black', label='Data Points')
    plt.plot(x, y_pred, color='red', linewidth=2, label='Regression Line')
    plt.annotate(line_eq,(ann_x,ann_y),fontsize=15,color="red")
    # Add titles and labels
    # title: Title of the plot (str)
    plt.title(title)
    # x_label: Label for the x-axis (str)
    plt.xlabel(x_label)
    # y_label: Label for the y-axis (str)
    plt.ylabel(y_label)
    plt.legend()
    plt.grid()

    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                         oyama  36.3000  139.8000     19.12        70
# 2                  kudahuvadhoo   2.6708   72.8944     28.63        78
# 6        hawaiian paradise park  19.5933 -154.9731     20.73        89
# 7                         tiksi  71.6872  128.8694     -3.32        81
# 9                        saipan  15.1355  145.7010     28.39        89
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                83        3.65      JP  1727107541
# 2                93        5.52      MV  1727107543
# 6                75        3.60      US  1727107056
# 7                93        3.26      RU  1727107549
# 9                40        1.54      MP  1727107175

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] <= 0]


# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                          adamstown -25.0660 -130.1015     19.63        83
# 3                          hithadhoo  -0.6000   73.0833     28.49        73
# 4                              rundu -17.9333   19.7667     32.35        19
# 5        edinburgh of the seven seas -37.0676  -12.3116     13.23        76
# 8                  port-aux-francais -49.3500   70.2167      1.35        84
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                99        5.50      PN  1727107460
# 3               100        4.24      MV  1727107544
# 4                83        2.53     NaN  1727107546
# 5                51        7.36      SH  1727107547
# 8                52       13.62      TF  1727107550

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
create_linear_regression_plot(
    northern_hemi_df['Lat'],
    northern_hemi_df['Max Temp'],
    ann_x = 5.8, 
    ann_y = 0.1,
    x_label='Latitude',
    y_label='Max Temperature (°C)',
    title='Max Temperature vs. Latitude in the Northern Hemisphere'
)
# Out:
# The r^2-value is: 0.701928880093701

# %%
# Linear regression on Southern Hemisphere
create_linear_regression_plot(
    southern_hemi_df['Lat'],
    southern_hemi_df['Max Temp'],
    ann_x = -25, 
    ann_y = 5.8,
    x_label='Latitude',
    y_label='Max Temperature (°C)',
    title='Max Temperature vs. Latitude in the Southern Hemisphere'
)
# Out:
# The r^2-value is: 0.5277803349691341

# %% [markdown]
# **Discussion about the linear relationship:** Our analysis supports that temperature decreases as one moves away from the equator, but other factors may can cause deviations from the expected linear relationship.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(
    northern_hemi_df['Lat'],
    northern_hemi_df['Humidity'],
    ann_x = 45, 
    ann_y = 20,
    x_label='Latitude',
    y_label='Humidity (%)',
    title='Humidity vs. Latitude in the Northern Hemisphere'
)
# Out:
# The r^2-value is: 0.0058812530688716665

# %%
# Southern Hemisphere
create_linear_regression_plot(
    southern_hemi_df['Lat'],
    southern_hemi_df['Humidity'],
    ann_x = -55, 
    ann_y = 45,
    x_label='Latitude',
    y_label='Humidity (%)',
    title='Humidity vs. Latitude in the Southern Hemisphere'
)
# Out:
# The r^2-value is: 8.647610171424171e-05

# %% [markdown]
# **Discussion about the linear relationship:** While latitude plays a significant role in determining temperature, its impact on humidity is far less direct and more heavily moderated by local and regional factors. This leads to a weaker linear relationship between humidity and latitude in comparison to temperature and latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(
    northern_hemi_df['Lat'],
    northern_hemi_df['Cloudiness'],
    ann_x = 46, 
    ann_y = 20,
    x_label='Latitude',
    y_label='Cloudiness (%)',
    title='Cloudiness vs. Latitude in the Northern Hemisphere'
)
# Out:
# The r^2-value is: 0.0002567852830712205

# %%
# Southern Hemisphere
create_linear_regression_plot(
    southern_hemi_df['Lat'],
    southern_hemi_df['Cloudiness'],
    ann_x = -55, 
    ann_y = 20,
    x_label='Latitude',
    y_label='Cloudiness (%)',
    title='Cloudiness vs. Latitude in the Southern Hemisphere'
)
# Out:
# The r^2-value is: 0.01001254513196431

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression analysis between cloudiness and latitude often shows little to no clear relationship. Proximity to large bodies of water or humid regions can increase cloudiness, while dry inland areas, regardless of latitude, often have less cloud cover.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(
    northern_hemi_df['Lat'],
    northern_hemi_df['Wind Speed'],
    ann_x = 2, 
    ann_y = 9.5,
    x_label='Latitude',
    y_label='Wind Speed m/s',
    title='Wind Speed vs. Latitude in the Northern Hemisphere'
)
# Out:
# The r^2-value is: 0.005744600361955807

# %%
# Southern Hemisphere
create_linear_regression_plot(
    southern_hemi_df['Lat'],
    southern_hemi_df['Wind Speed'],
    ann_x = -55, 
    ann_y = 9,
    x_label='Latitude',
    y_label='Wind Speed m/s',
    title='Wind Speed vs. Latitude in the Southern Hemisphere'
)
# Out:
# The r^2-value is: 0.1112084549376036

# %% [markdown]
# **Discussion about the linear relationship:** Global atmospheric circulation does create some regional wind patterns based on latitude, the relationship between wind speed and latitude is weak due to the strong influence of other factors.
